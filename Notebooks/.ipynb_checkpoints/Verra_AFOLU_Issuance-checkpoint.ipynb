# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 5
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
# ----> 5 import excel
#
# ModuleNotFoundError: No module named 'excel'

# %%
df = pd.read_csv('../Data/vcus_92122.csv')

# %%
df.head()
# Out:
#   Issuance Date Sustainable Development Goals Vintage Start Vintage End   ID  \
# 0    20/09/2022                           NaN    25/02/2013  24/02/2014  953
# 1    20/09/2022                           NaN    25/02/2014  24/02/2015  953
# 2    20/09/2022                           NaN    25/02/2015  24/02/2016  953
# 3    20/09/2022                           NaN    25/02/2016  24/02/2017  953
# 4    20/09/2022                           NaN    25/02/2017  24/02/2018  953
#
#                                                 Name   Country  \
# 0  The Paraguay Forest Conservation Project - Red...  Paraguay
# 1  The Paraguay Forest Conservation Project - Red...  Paraguay
# 2  The Paraguay Forest Conservation Project - Red...  Paraguay
# 3  The Paraguay Forest Conservation Project - Red...  Paraguay
# 4  The Paraguay Forest Conservation Project - Red...  Paraguay
#
#                               Project Type Methodology  \
# 0  Agriculture Forestry and Other Land Use      VM0007
# ...

# %%
df_country = df.groupby(by='Country').sum()

# %%
df_country.head()
# Out:
#                  ID  Total Vintage Quantity  Quantity Issued
# Country
# Australia     23717                 5751095           123013
# Belize       222309               116775436          1252097
# Bolivia         818                   55400            20000
# Brazil     30548850             21376524043         61143439
# Cambodia    4970512              6544995229         39007689

# %%
df_country.sort_values(by='Quantity Issued', ascending=False, inplace=True)

# %%
df_country.head()
# Out:
#                  ID  Total Vintage Quantity  Quantity Issued
# Country
# Indonesia   7110754             30364480301         67907263
# Peru        9395178             21479981860         62282778
# Brazil     30548850             21376524043         61143439
# Cambodia    4970512              6544995229         39007689
# Colombia    2980435              5834871931         31110963

# %%
fig, ax = plt.subplots()

ax = plt.bar(x=df_country.head().index, height=df_country['Quantity Issued'].head().values)

# %%
indo = df.loc[df['Country'] == 'Indonesia']

# %%
indo.head()
# Out:
#     Issuance Date Sustainable Development Goals Vintage Start Vintage End  \
# 90     19/07/2022                           NaN    01/01/2020  31/12/2020
# 127    28/06/2022                           NaN    01/01/2019  31/12/2019
# 278    19/05/2022                           NaN    01/01/2020  31/12/2020
# 324    05/05/2022                           NaN    01/01/2020  31/12/2020
# 371    03/05/2022                           NaN    01/01/2019  31/12/2019
#
#        ID                                    Name    Country  \
# 90   1899  Sumatra Merang Peatland Project (SMPP)  Indonesia
# 127  1899  Sumatra Merang Peatland Project (SMPP)  Indonesia
# 278  1899  Sumatra Merang Peatland Project (SMPP)  Indonesia
# 324  1899  Sumatra Merang Peatland Project (SMPP)  Indonesia
# 371  1899  Sumatra Merang Peatland Project (SMPP)  Indonesia
#
#                                 Project Type Methodology  \
# 90   Agriculture Forestry and Other Land Use      VM0007
# ...

# %%
indo_proj = indo.groupby('Name').sum()

# %%
len(indo_proj)
# Out:
# 4

# %%
indo_proj["Quantity Issued"].sum()
# Out:
# 67907263

# %%
indo_proj
# Out:
#                                                          ID  \
# Name
# Katingan Peatland Restoration and Conservation ...  1310099
# Mangrove restoration and coastal greenbelt prot...    50762
# Rimba Raya Biodiversity Reserve Project             5489730
# Sumatra Merang Peatland Project (SMPP)               260163
#
#                                                     Total Vintage Quantity  \
# Name
# Katingan Peatland Restoration and Conservation ...              6673616836
# Mangrove restoration and coastal greenbelt prot...                 6750207
# Rimba Raya Biodiversity Reserve Project                        23611813818
# Sumatra Merang Peatland Project (SMPP)                            72299440
#
#                                                     Quantity Issued
# Name
# Katingan Peatland Restoration and Conservation ...         38581777
# Mangrove restoration and coastal greenbelt prot...           397071
# ...
